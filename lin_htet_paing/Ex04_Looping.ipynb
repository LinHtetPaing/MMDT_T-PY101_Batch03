# %% [markdown]
# <a href="https://colab.research.google.com/github/myothida/PythonProgramming/blob/main/Ex4_Looping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The exercises are extracted from A_Practical_Introduction_to_Python_Programming_Heinold.pdf

# %% [markdown]
# Ex 1: Write a program that uses a while loop (not a for loop) to read through a string and print
# the characters of the string one-by-one on separate lines.

# %%
user_string = input("Enter a sentence: ")
string_length = len(user_string)
index = 0
while(string_length > index):
  print(user_string[index])
  index += 1
# Out:
# Enter a sentence: this is the great
# t
# h
# i
# s
#
# i
# s
#
# t
# h
# e
#
# g
# r
# e
# a
# t

# %% [markdown]
# Ex 2: A good program will make sure that the data its users enter is valid. Write a program that
# asks the user for a weight and converts it from kilograms to pounds. Whenever the user
# enters a weight below 0, the program should tell them that their entry is invalid and then ask
# them again to enter a weight. [Hint: Use a while loop, not an if statement].

# %%
isValid = False
while(isValid == False):
  userInput = float(input("Enter weigth in Kiligrams"))
  if (userInput >= 0):
    print("{} kilogram is {} pound".format(userInput, userInput * 2.20462))
    isValid = True
# Out:
# Enter weigth in Kiligrams-1
# Enter weigth in Kiligrams-2
# Enter weigth in Kiligrams10
# 10.0 kilogram is 22.0462 pound

# %% [markdown]
# Ex 3: Write a program that allows the user to enter any number of test scores. The user indicates
# they are done by entering in a negative number. Print how many of the scores are A’s (90 or
# above). Also print out the average

# %%
scores = 0
index = 0
isLoop = True
while(isLoop == True):
  user_test_score = int(input("Enter any number of test scores: "))
  if user_test_score >= 90:
    scores += user_test_score
    index += 1
  elif user_test_score >= 0:
    scores += user_test_score
    index += 1
  else:
    isLoop = False
print("Average is {}".format(scores/index))
# Out:
# Enter any number of test scores: 90
# Enter any number of test scores: 100
# Enter any number of test scores: 200
# Enter any number of test scores: -1
# Average is 130.0

# %% [markdown]
# Ex 4: Write a program that asks the user for a string and a letter. Using a for loop, the
# program should print the index of the first occurrence of that letter and a message if the
# string does not contain the letter.

# %%
user_string = input("Enter a string: ")
user_letter = input("Enter a letter: ")
is_contain = False
for index in range(len(user_string)):
  if (user_letter == user_string[index]):
    print("The index of first occurance is {}".format(index))
    is_contain = True
    break
if (is_contain == False):
  print("The string does not contain the letter")
# Out:
# Enter a string: This a is a string
# Enter a letter: a
# The index of first occurance is 5

# %% [markdown]
# Ex 5: Write a program in which you have a list that contains seven integers that can be 0 or 1. Find the first zero entry in the list and change it to a 1. If there are no zero entries, print a message saying so.

# %%
user_input = input("Enter a list of 7 integers: ")
is_changed = False
for index in range(len(user_input)):
  if user_input[index] == '0' and is_changed == False:
    user_input = user_input.replace('0','1', 1)
    is_changed = True
    break
if is_changed == False:
  print("There are no zero entries")
else:
  print("The first zero entry int the list and change from 0 to 1 is {}".format(user_input))
# Out:
# Enter a list of 7 integers: 0123120123
# The first zero entry int the list and change from 0 to 1 is 1123120123
